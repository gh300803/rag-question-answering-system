# %% [markdown]
# # COMP64702 RAG Coursework
# ## Notebook 1: Corpus and Benchmark
# Chosen cuisine: South Asian cuisine
#
# This notebook loads and inspects the background corpus and benchmark dataset
# used for the RAG system.

# %%
# Imports

import json
from pathlib import Path
import pandas as pd

# %%
# File paths

corpus_path = "background_corpus.json"
benchmark_path = "benchmark_dataset.json"
benchmark_input_path = "benchmark_input_only.json"

# %%
# Load corpus

with open(corpus_path, "r", encoding="utf-8") as f:
    corpus = json.load(f)

print(f"Loaded {len(corpus)} corpus documents")
# Out:
# Loaded 17 corpus documents

# %%
# Show corpus summary

corpus_df = pd.DataFrame([
    {
        "doc_id": d.get("doc_id"),
        "title": d.get("title"),
        "source": d.get("source"),
        "char_count": d.get("char_count", len(d.get("full_text", "")))
    }
    for d in corpus
])

corpus_df
# Out:
#                       doc_id                title     source  char_count
# 0    wiki_sri_lankan_cuisine   Sri Lankan cuisine  wikipedia       10402
# 1                  wiki_naan                 Naan  wikipedia        4690
# 2              wiki_turmeric             Turmeric  wikipedia       14629
# 3                 wiki_cumin                Cumin  wikipedia       12384
# 4              wiki_cardamom             Cardamom  wikipedia       13295
# 5        wiki_indian_cuisine       Indian cuisine  wikipedia        2278
# 6     wiki_pakistani_cuisine    Pakistani cuisine  wikipedia        1603
# 7   wiki_bangladeshi_cuisine  Bangladeshi cuisine  wikipedia        1311
# 8        wiki_nepali_cuisine       Nepali cuisine  wikipedia        1248
# 9               wiki_biryani              Biryani  wikipedia        1301
# 10                wiki_curry                Curry  wikipedia        1265
# 11                 wiki_dosa                 Dosa  wikipedia        1148
# 12               wiki_samosa               Samosa  wikipedia        1149
# 13     wiki_tandoori_chicken     Tandoori chicken  wikipedia         420
# 14                  wiki_dal                  Dal  wikipedia         430
# 15                 wiki_roti                 Roti  wikipedia         360
# 16                wiki_pilaf                Pilaf  wikipedia         470

# %%
# Show one example document

example_doc = corpus[0]
print("TITLE:", example_doc["title"])
print("DOC ID:", example_doc["doc_id"])
print("SOURCE:", example_doc["source"])
print()
print(example_doc["full_text"][:1500])
# Out:
# TITLE: Sri Lankan cuisine
# DOC ID: wiki_sri_lankan_cuisine
# SOURCE: wikipedia
#
# Sri Lankan cuisine is known for its particular combinations of herbs, spices, fish, vegetables, rices , and fruits. The cuisine is highly centered around many varieties of rice, as well as coconut which is a ubiquitous plant throughout the country. Seafood also plays a significant role in the cuisine, be it fresh fish or preserved fish. As a country that was a hub in the historic oceanic silk road , contact with foreign traders brought new food items and cultural influences in addition to the local traditions of the country's ethnic groups, all of which have helped shape Sri Lankan cuisine. Influences from Indian (particularly South Indian ), Indonesian and Dutch cuisines are most evident with Sri Lankan cuisine sharing close ties to other neighbouring South and Southeast Asian cuisines .
#
# Sri Lanka is historically famous for its cinnamon. The 'true cinnamon' tree, or Cinnamomum verum , used to be botanically named Cinnamomum zeylanicum to reflect its Sri Lankan origins. This is a widely utilized spice in Sri Lanka, and has a more delicate, sweet taste in comparison to Cinnamomum cassia , which is more common in some other Southeast Asian cuisines. Contrasting the local cuisine with those of neighbouring regions, Sri Lankan cuisine is characterized by unique spice blends with heavy use of Sri Lankan cinnamon and black pepper, as well as by the use of ingredients such as Maldives fish , goraka ( Garcinia cambogia ), pandan leaf , lemongrass , and jaggery made from kithul palm

# %%
# Load benchmark dataset

with open(benchmark_path, "r", encoding="utf-8") as f:
    benchmark = json.load(f)

print(f"Loaded {len(benchmark)} benchmark questions")
# Out:
# Loaded 13 benchmark questions

# %%
# Show benchmark summary

benchmark_df = pd.DataFrame(benchmark)
benchmark_df[["query_id", "query", "answer_source", "question_type", "difficulty"]]
# Out:
#    query_id                                              query  \
# 0    sa_000  What is biryani and which region is it origina...
# 1    sa_001  What distinguishes Hyderabadi biryani from Luc...
# 2    sa_002      What is the difference between naan and roti?
# 3    sa_003         How is dosa batter traditionally prepared?
# 4    sa_004  What ingredients are used in a classic samosa ...
# 5    sa_005  What is cardamom and what are the differences ...
# 6    sa_006  How does Sri Lankan cuisine differ from South ...
# 7    sa_007  What is the difference between a curry and a m...
# 8    sa_008  What are the key features of Pakistani cuisine...
# 9    sa_009  What is butter chicken and where did it origin...
# 10   sa_010    How is tandoori chicken traditionally prepared?
# 11   sa_011  What is dal and why is it important in South A...
# 12   sa_012  What is the difference between biryani and pilaf?
#
#               answer_source question_type difficulty
# 0              wiki_biryani       factual       easy
# 1              wiki_biryani   comparative       hard
# 2                 wiki_naan   comparative       easy
# 3                 wiki_dosa    procedural     medium
# 4               wiki_samosa    procedural     medium
# 5             wiki_cardamom    ingredient       hard
# 6   wiki_sri_lankan_cuisine   comparative       hard
# 7                wiki_curry   comparative     medium
# 8    wiki_pakistani_cuisine   comparative       hard
# 9       wiki_butter_chicken       factual       easy
# 10    wiki_tandoori_chicken    procedural       easy
# 11                 wiki_dal       factual       easy
# 12             wiki_biryani   comparative     medium

# %%
# Load benchmark input-only file

with open(benchmark_input_path, "r", encoding="utf-8") as f:
    benchmark_input = json.load(f)

print(f"Loaded {len(benchmark_input['queries'])} input-only queries")
benchmark_input["queries"][:3]
# Out:
# Loaded 13 input-only queries
# [{'query_id': 'sa_000',
#   'query': 'What is biryani and which region is it originally associated with?'},
#  {'query_id': 'sa_001',
#   'query': 'What distinguishes Hyderabadi biryani from Lucknowi (Awadhi) biryani?'},
#  {'query_id': 'sa_002',
#   'query': 'What is the difference between naan and roti?'}]

# %% [markdown]
# # State:
#
# corpus contains 13 documents
#
# benchmark contains 9 questions
#
# benchmark questions are aligned with corpus content
